# %%
import numpy as np
from os import listdir

# %% [markdown]
# 核函数转换

# %%
def kernelTrans(X, A, kTup):
    m, n = np.shape(X)
    K = np.mat(np.zeros((m, 1)))
    if kTup[0] == 'lin':
        K = X * A.T
    elif kTup[0] == 'rbf':
        for j in range(m):
            deltaRow = X[j, :] - A
            K[j] = deltaRow * deltaRow.T
        K = np.exp(K / (-1 * kTup[1]**2))
    else:
        raise NameError('Houston We Have a Problem That Kernel is not recongnized')
    return K

# %% [markdown]
# Platt SMO支持函数

# %%
class optStruct:
    def __init__(self, dataMatIn, classLabels, C, toler, kTup):
        self.X = dataMatIn
        self.labelMat = classLabels
        self.C = C
        self.tol = toler
        self.m = np.shape(dataMatIn)[0]
        self.alphas = np.mat(np.zeros((self.m, 1)))
        self.b = 0
        self.eCache = np.mat(np.zeros((self.m, 2)))    # 误差缓存
        self.K = np.mat(np.zeros((self.m, self.m)))
        for i in range(self.m):
            self.K[:, i] = kernelTrans(self.X, self.X[i, :], kTup)
            
# 计算E值并返回
def calcEk(oS, k):
    fXk = float(np.multiply(oS.alphas, oS.labelMat).T * oS.K[:, k] + oS.b)
    Ek = fXk - float(oS.labelMat[k])
    return Ek

# 选择内循环的alpha值
def selectJ(i, oS, Ei):
    maxK = -1
    maxDeltaE = 0
    Ej = 0
    oS.eCache[i] = [1, Ei]
    validecachelist = np.nonzero(oS.eCache[:, 0].A)[0]    # 返回非0的E值对应的alpha值
    if len(validecachelist) > 1:
        for k in validecachelist:
            if k == i:
                continue
            Ek = calcEk(oS, k)
            deltaE = abs(Ei - Ek)
            if deltaE > maxDeltaE:    # 选择具有最大步长的j
                maxK = k
                maxDeltaE = deltaE
                Ej = Ek
        return maxK, Ej
    else:
        j = selectJrand(i, oS.m)
        Ej = calcEk(oS, j)
    return j, Ej

def updateEk(oS, k):
    Ek = calcEk(oS, k)
    oS.eCache[k] = [1, Ek]

# i是alpha下标，m是alpha数目
def selectJrand(i, m):
    j = i;
    while j == i:
        j = int(np.random.uniform(0, m))
    return j

# 调整大于H或小于L的alpha值
def clipAlpha(aj, H, L):
    if aj > H:
        aj = H
    if L > aj:
        aj = L
    return aj

# %% [markdown]
# Platt SMO优化例程

# %%
def innerL(i, oS):
    Ei = calcEk(oS, i)
    if ((oS.labelMat[i] * Ei < -oS.tol) and (oS.alphas[i] < oS.C)) or ((oS.labelMat[i] * Ei > oS.tol) and (oS.alphas[i] >0)):
        j ,Ej = selectJ(i, oS, Ei)
        alphaIold = oS.alphas[i].copy()
        alphaJold = oS.alphas[j].copy()
        # 保证alpha在0与C之间
        if oS.labelMat[i] != oS.labelMat[j]:
            L = max(0, oS.alphas[j] - oS.alphas[i])
            H = min(oS.C, oS.C + oS.alphas[j] - oS.alphas[i])
        else:
            L = max(0, oS.alphas[j] - oS.alphas[i] - oS.C)
            H = min(oS.C, oS.alphas[j] - oS.alphas[i])
        if L == H:
            print('L == H')
            return 0
        # alpha[j]的最优修改量
        eta = 2.0 * oS.K[i, j] - oS.K[i, i] - oS.K[j, j]
        if eta >= 0:
            print('eta >= 0')
            return 0
        # 计算新的alpha[j]
        oS.alphas[j] -= oS.labelMat[j] * (Ei - Ej) / eta
        oS.alphas[j] = clipAlpha(oS.alphas[j], H, L)
        updateEk(oS, i)
        # 设置常数项b
        b1 = oS.b - Ei - oS.labelMat[i] * (oS.alphas[i] - alphaIold) * oS.K[i, i] - oS.labelMat[j] * (oS.alphas[j] - alphaJold) * oS.K[i, j]
        b2 = oS.b - Ej - oS.labelMat[i] * (oS.alphas[i] - alphaIold) * oS.K[i, j] - oS.labelMat[j] * (oS.alphas[j] - alphaJold) * oS.K[j, j]
        if 0 < oS.alphas[i] and oS.C > oS.alphas[i]:
            oS.b = b1
        elif 0 < oS.alphas[j] and oS.C > oS.alphas[j]:
            oS.b = b2
        else:
            oS.b = (b1 + b2)/2.0
        return 1
    else:
        return 0

# %% [markdown]
# Platt SMO外循环代码

# %%
def smoP(dataMatIn, classLabels, C, toler, maxIter, kTup=('lin', 0)):
    oS = optStruct(np.mat(dataMatIn), np.mat(classLabels).transpose(), C, toler, kTup)
    iter = 0
    entireSet = True
    alphaPairsChanged = 0
    while iter < maxIter and (alphaPairsChanged > 0 or entireSet):
        alphaPairsChanged = 0
        if entireSet:    # 遍历所有值
            for i in range(oS.m):
                alphaPairsChanged += innerL(i,oS)
                print('fullSet, iter: %d i: %d, pairs changed %d' % (iter, i, alphaPairsChanged))
            iter += 1
        else:    # 遍历非边界值
            nonBoundIs = np.nonzero((oS.alphas.A > 0) * (oS.alphas.A < C))[0]
            for i in nonBoundIs:
                alphaPairsChanged += innerL(i, oS)
                print('non-bound, iter: %d i: %d, pairs changed %d' % (iter, i, alphaPairsChanged))
            iter += 1
        if entireSet:
            entireSet = False
        elif alphaPairsChanged == 0:
            entireSet = True
        print('iteration number: %d' % iter)
    return oS.b, oS.alphas

# %% [markdown]
# 计算w

# %%
def calcWs(alphas, dataArr, classLabels):
    X = np.mat(dataArr)
    labelMat = np.mat(classLabels).transpose()
    m, n = np.shape(X)
    w = np.zeros((n, 1))
    for i in range(m):
        w += np.multiply(alphas[i] * labelMat[i], X[i, :].T)
    return w

# %% [markdown]
# 将文件信息读取为向量 32\*32 ——> 1\*1024

# %%
def img2vector(filename):
    # 创建一个 1*1024 的的数组 
    returnVect = np.zeros((1,1024))
    fr = open(filename)
    for i in range(32):
        # 读取文件
        lineStr = fr.readline()
        for j in range(32):
            # 存储每行前32个字符值
            returnVect[0,32*i+j] = int(lineStr[j])
    return returnVect

# %%
def loadImages(dirName):
    hwLabels = []
    trainingFileList = listdir(dirName)
    m = len(trainingFileList)
    trainingMat = np.zeros((m, 1024))
    for i in range(m):
        fileNameStr = trainingFileList[i]
        fileStr = fileNameStr.split('.')[0]
        classNumStr = int(fileStr.split('_')[0])
        if classNumStr == 9:
            hwLabels.append(-1)
        else:
            hwLabels.append(1)
        trainingMat[i, :] = img2vector('%s/%s' % (dirName, fileNameStr))
    return trainingMat, hwLabels

def testDigits(kTup=('rbf', 10)):
    dataArr, labelArr = loadImages('digits/trainingDigits')
    b, alphas = smoP(dataArr, labelArr, 200, 0.0001, 1000, kTup)
    datMat = np.mat(dataArr)
    labelMat = np.mat(labelArr).transpose()
    svInd = np.nonzero(alphas.A > 0)[0]
    sVs = datMat[svInd]
    labelSV = labelMat[svInd]
    print('there are %d Support Vectors' % np.shape(sVs)[0])
    m, n = np.shape(datMat)
    errorCount = 0
    for i in range(m):
        kernelEval = kernelTrans(sVs, datMat[i, :], kTup)
        predict = kernelEval.T * np.multiply(labelSV, alphas[svInd]) + b
        if np.sign(predict) != np.sign(labelArr[i]):
            errorCount += 1
    print('the training error rate is: %f' % (float(errorCount)/m))
    dataArr, labelArr = loadImages('digits/testDigits')
    errorCount = 0
    datMat = np.mat(dataArr)
    labelMat = np.mat(labelArr).transpose()
    m, n = np.shape(datMat)
    for i in range(m):
        kernelEval = kernelTrans(sVs, datMat[i, :], kTup)
        predict = kernelEval.T * np.multiply(labelSV, alphas[svInd]) + b
        if np.sign(predict) != np.sign(labelArr[i]):
            errorCount += 1
    print('the test error rate is: %f' % (float(errorCount)/m))

# %%
testDigits(('rbf', 20))
# Out:
# L == H
# fullSet, iter: 0 i: 0, pairs changed 0
# fullSet, iter: 0 i: 1, pairs changed 1
# L == H
# fullSet, iter: 0 i: 2, pairs changed 1
# L == H
# fullSet, iter: 0 i: 3, pairs changed 1
# L == H
# fullSet, iter: 0 i: 4, pairs changed 1
# L == H
# fullSet, iter: 0 i: 5, pairs changed 1
# L == H
# fullSet, iter: 0 i: 6, pairs changed 1
# L == H
# fullSet, iter: 0 i: 7, pairs changed 1
# L == H
# fullSet, iter: 0 i: 8, pairs changed 1
# L == H
# fullSet, iter: 0 i: 9, pairs changed 1
# L == H
# fullSet, iter: 0 i: 10, pairs changed 1
# L == H
# fullSet, iter: 0 i: 11, pairs changed 1
# L == H
# fullSet, iter: 0 i: 12, pairs changed 1
# L == H
# fullSet, iter: 0 i: 13, pairs changed 1
# L == H
# fullSet, iter: 0 i: 14, pairs changed 1
# L == H
# fullSet, iter: 0 i: 15, pairs changed 1
# L == H
# fullSet, iter: 0 i: 16, pairs changed 1
# L == H
# fullSet, iter: 0 i: 17, pairs changed 1
# L == H
# fullSet, iter: 0 i: 18, pairs changed 1
# L == H
# fullSet, iter: 0 i: 19, pairs changed 1
# L == H
# fullSet, iter: 0 i: 20, pairs changed 1
# L == H
# fullSet, iter: 0 i: 21, pairs changed 1
# L == H
# fullSet, iter: 0 i: 22, pairs changed 1
# L == H
# fullSet, iter: 0 i: 23, pairs changed 1
# L == H
# fullSet, iter: 0 i: 24, pairs changed 1
# L == H
# fullSet, iter: 0 i: 25, pairs changed 1
# L == H
# fullSet, iter: 0 i: 26, pairs changed 1
# L == H
# fullSet, iter: 0 i: 27, pairs changed 1
# L == H
# fullSet, iter: 0 i: 28, pairs changed 1
# L == H
# fullSet, iter: 0 i: 29, pairs changed 1
# L == H
# fullSet, iter: 0 i: 30, pairs changed 1
# L == H
# fullSet, iter: 0 i: 31, pairs changed 1
# L == H
# fullSet, iter: 0 i: 32, pairs changed 1
# L == H
# fullSet, iter: 0 i: 33, pairs changed 1
# L == H
# fullSet, iter: 0 i: 34, pairs changed 1
# L == H
# fullSet, iter: 0 i: 35, pairs changed 1
# L == H
# fullSet, iter: 0 i: 36, pairs changed 1
# L == H
# fullSet, iter: 0 i: 37, pairs changed 1
# L == H
# fullSet, iter: 0 i: 38, pairs changed 1
# L == H
# fullSet, iter: 0 i: 39, pairs changed 1
# L == H
# fullSet, iter: 0 i: 40, pairs changed 1
# L == H
# fullSet, iter: 0 i: 41, pairs changed 1
# L == H
# fullSet, iter: 0 i: 42, pairs changed 1
# L == H
# fullSet, iter: 0 i: 43, pairs changed 1
# L == H
# fullSet, iter: 0 i: 44, pairs changed 1
# L == H
# fullSet, iter: 0 i: 45, pairs changed 1
# L == H
# fullSet, iter: 0 i: 46, pairs changed 1
# L == H
# fullSet, iter: 0 i: 47, pairs changed 1
# L == H
# fullSet, iter: 0 i: 48, pairs changed 1
# L == H
# fullSet, iter: 0 i: 49, pairs changed 1
# L == H
# fullSet, iter: 0 i: 50, pairs changed 1
# L == H
# fullSet, iter: 0 i: 51, pairs changed 1
# L == H
# fullSet, iter: 0 i: 52, pairs changed 1
# L == H
# fullSet, iter: 0 i: 53, pairs changed 1
# L == H
# fullSet, iter: 0 i: 54, pairs changed 1
# L == H
# fullSet, iter: 0 i: 55, pairs changed 1
# L == H
# fullSet, iter: 0 i: 56, pairs changed 1
# L == H
# fullSet, iter: 0 i: 57, pairs changed 1
# L == H
# fullSet, iter: 0 i: 58, pairs changed 1
# L == H
# fullSet, iter: 0 i: 59, pairs changed 1
# L == H
# fullSet, iter: 0 i: 60, pairs changed 1
# L == H
# fullSet, iter: 0 i: 61, pairs changed 1
# L == H
# fullSet, iter: 0 i: 62, pairs changed 1
# L == H
# fullSet, iter: 0 i: 63, pairs changed 1
# L == H
# fullSet, iter: 0 i: 64, pairs changed 1
# L == H
# fullSet, iter: 0 i: 65, pairs changed 1
# L == H
# fullSet, iter: 0 i: 66, pairs changed 1
# L == H
# fullSet, iter: 0 i: 67, pairs changed 1
# L == H
# fullSet, iter: 0 i: 68, pairs changed 1
# L == H
# fullSet, iter: 0 i: 69, pairs changed 1
# L == H
# fullSet, iter: 0 i: 70, pairs changed 1
# L == H
# fullSet, iter: 0 i: 71, pairs changed 1
# L == H
# fullSet, iter: 0 i: 72, pairs changed 1
# L == H
# fullSet, iter: 0 i: 73, pairs changed 1
# L == H
# fullSet, iter: 0 i: 74, pairs changed 1
# L == H
# fullSet, iter: 0 i: 75, pairs changed 1
# L == H
# fullSet, iter: 0 i: 76, pairs changed 1
# L == H
# fullSet, iter: 0 i: 77, pairs changed 1
# L == H
# fullSet, iter: 0 i: 78, pairs changed 1
# L == H
# fullSet, iter: 0 i: 79, pairs changed 1
# L == H
# fullSet, iter: 0 i: 80, pairs changed 1
# L == H
# fullSet, iter: 0 i: 81, pairs changed 1
# L == H
# fullSet, iter: 0 i: 82, pairs changed 1
# L == H
# fullSet, iter: 0 i: 83, pairs changed 1
# L == H
# fullSet, iter: 0 i: 84, pairs changed 1
# L == H
# fullSet, iter: 0 i: 85, pairs changed 1
# L == H
# fullSet, iter: 0 i: 86, pairs changed 1
# L == H
# fullSet, iter: 0 i: 87, pairs changed 1
# L == H
# fullSet, iter: 0 i: 88, pairs changed 1
# L == H
# fullSet, iter: 0 i: 89, pairs changed 1
# L == H
# fullSet, iter: 0 i: 90, pairs changed 1
# L == H
# fullSet, iter: 0 i: 91, pairs changed 1
# L == H
# fullSet, iter: 0 i: 92, pairs changed 1
# L == H
# fullSet, iter: 0 i: 93, pairs changed 1
# L == H
# fullSet, iter: 0 i: 94, pairs changed 1
# L == H
# fullSet, iter: 0 i: 95, pairs changed 1
# L == H
# fullSet, iter: 0 i: 96, pairs changed 1
# L == H
# fullSet, iter: 0 i: 97, pairs changed 1
# L == H
# fullSet, iter: 0 i: 98, pairs changed 1
# L == H
# fullSet, iter: 0 i: 99, pairs changed 1
# L == H
# fullSet, iter: 0 i: 100, pairs changed 1
# L == H
# fullSet, iter: 0 i: 101, pairs changed 1
# L == H
# fullSet, iter: 0 i: 102, pairs changed 1
# L == H
# fullSet, iter: 0 i: 103, pairs changed 1
# L == H
# fullSet, iter: 0 i: 104, pairs changed 1
# L == H
# fullSet, iter: 0 i: 105, pairs changed 1
# L == H
# fullSet, iter: 0 i: 106, pairs changed 1
# L == H
# fullSet, iter: 0 i: 107, pairs changed 1
# L == H
# fullSet, iter: 0 i: 108, pairs changed 1
# L == H
# fullSet, iter: 0 i: 109, pairs changed 1
# L == H
# fullSet, iter: 0 i: 110, pairs changed 1
# L == H
# fullSet, iter: 0 i: 111, pairs changed 1
# L == H
# fullSet, iter: 0 i: 112, pairs changed 1
# L == H
# fullSet, iter: 0 i: 113, pairs changed 1
# L == H
# fullSet, iter: 0 i: 114, pairs changed 1
# L == H
# fullSet, iter: 0 i: 115, pairs changed 1
# L == H
# fullSet, iter: 0 i: 116, pairs changed 1
# L == H
# fullSet, iter: 0 i: 117, pairs changed 1
# L == H
# fullSet, iter: 0 i: 118, pairs changed 1
# L == H
# fullSet, iter: 0 i: 119, pairs changed 1
# L == H
# fullSet, iter: 0 i: 120, pairs changed 1
# L == H
# fullSet, iter: 0 i: 121, pairs changed 1
# L == H
# fullSet, iter: 0 i: 122, pairs changed 1
# L == H
# fullSet, iter: 0 i: 123, pairs changed 1
# L == H
# fullSet, iter: 0 i: 124, pairs changed 1
# L == H
# fullSet, iter: 0 i: 125, pairs changed 1
# L == H
# fullSet, iter: 0 i: 126, pairs changed 1
# L == H
# fullSet, iter: 0 i: 127, pairs changed 1
# L == H
# fullSet, iter: 0 i: 128, pairs changed 1
# L == H
# fullSet, iter: 0 i: 129, pairs changed 1
# L == H
# fullSet, iter: 0 i: 130, pairs changed 1
# L == H
# fullSet, iter: 0 i: 131, pairs changed 1
# L == H
# fullSet, iter: 0 i: 132, pairs changed 1
# L == H
# fullSet, iter: 0 i: 133, pairs changed 1
# L == H
# fullSet, iter: 0 i: 134, pairs changed 1
# L == H
# fullSet, iter: 0 i: 135, pairs changed 1
# L == H
# fullSet, iter: 0 i: 136, pairs changed 1
# L == H
# fullSet, iter: 0 i: 137, pairs changed 1
# L == H
# fullSet, iter: 0 i: 138, pairs changed 1
# L == H
# fullSet, iter: 0 i: 139, pairs changed 1
# L == H
# fullSet, iter: 0 i: 140, pairs changed 1
# L == H
# fullSet, iter: 0 i: 141, pairs changed 1
# L == H
# fullSet, iter: 0 i: 142, pairs changed 1
# L == H
# fullSet, iter: 0 i: 143, pairs changed 1
# L == H
# fullSet, iter: 0 i: 144, pairs changed 1
# L == H
# fullSet, iter: 0 i: 145, pairs changed 1
# L == H
# fullSet, iter: 0 i: 146, pairs changed 1
# L == H
# fullSet, iter: 0 i: 147, pairs changed 1
# L == H
# fullSet, iter: 0 i: 148, pairs changed 1
# L == H
# fullSet, iter: 0 i: 149, pairs changed 1
# L == H
# fullSet, iter: 0 i: 150, pairs changed 1
# L == H
# fullSet, iter: 0 i: 151, pairs changed 1
# L == H
# fullSet, iter: 0 i: 152, pairs changed 1
# L == H
# fullSet, iter: 0 i: 153, pairs changed 1
# L == H
# fullSet, iter: 0 i: 154, pairs changed 1
# L == H
# fullSet, iter: 0 i: 155, pairs changed 1
# L == H
# fullSet, iter: 0 i: 156, pairs changed 1
# L == H
# fullSet, iter: 0 i: 157, pairs changed 1
# L == H
# fullSet, iter: 0 i: 158, pairs changed 1
# L == H
# fullSet, iter: 0 i: 159, pairs changed 1
# L == H
# fullSet, iter: 0 i: 160, pairs changed 1
# L == H
# fullSet, iter: 0 i: 161, pairs changed 1
# L == H
# fullSet, iter: 0 i: 162, pairs changed 1
# L == H
# fullSet, iter: 0 i: 163, pairs changed 1
# L == H
# fullSet, iter: 0 i: 164, pairs changed 1
# L == H
# fullSet, iter: 0 i: 165, pairs changed 1
# L == H
# fullSet, iter: 0 i: 166, pairs changed 1
# L == H
# fullSet, iter: 0 i: 167, pairs changed 1
# L == H
# fullSet, iter: 0 i: 168, pairs changed 1
# L == H
# fullSet, iter: 0 i: 169, pairs changed 1
# L == H
# fullSet, iter: 0 i: 170, pairs changed 1
# L == H
# fullSet, iter: 0 i: 171, pairs changed 1
# L == H
# fullSet, iter: 0 i: 172, pairs changed 1
# L == H
# fullSet, iter: 0 i: 173, pairs changed 1
# L == H
# fullSet, iter: 0 i: 174, pairs changed 1
# L == H
# fullSet, iter: 0 i: 175, pairs changed 1
# L == H
# fullSet, iter: 0 i: 176, pairs changed 1
# L == H
# fullSet, iter: 0 i: 177, pairs changed 1
# L == H
# fullSet, iter: 0 i: 178, pairs changed 1
# L == H
# fullSet, iter: 0 i: 179, pairs changed 1
# L == H
# fullSet, iter: 0 i: 180, pairs changed 1
# L == H
# fullSet, iter: 0 i: 181, pairs changed 1
# L == H
# fullSet, iter: 0 i: 182, pairs changed 1
# L == H
# fullSet, iter: 0 i: 183, pairs changed 1
# L == H
# fullSet, iter: 0 i: 184, pairs changed 1
# L == H
# fullSet, iter: 0 i: 185, pairs changed 1
# L == H
# fullSet, iter: 0 i: 186, pairs changed 1
# L == H
# fullSet, iter: 0 i: 187, pairs changed 1
# L == H
# fullSet, iter: 0 i: 188, pairs changed 1
# L == H
# fullSet, iter: 0 i: 189, pairs changed 1
# L == H
# fullSet, iter: 0 i: 190, pairs changed 1
# L == H
# fullSet, iter: 0 i: 191, pairs changed 1
# L == H
# fullSet, iter: 0 i: 192, pairs changed 1
# L == H
# fullSet, iter: 0 i: 193, pairs changed 1
# L == H
# fullSet, iter: 0 i: 194, pairs changed 1
# L == H
# fullSet, iter: 0 i: 195, pairs changed 1
# L == H
# fullSet, iter: 0 i: 196, pairs changed 1
# L == H
# fullSet, iter: 0 i: 197, pairs changed 1
# L == H
# fullSet, iter: 0 i: 198, pairs changed 1
# L == H
# fullSet, iter: 0 i: 199, pairs changed 1
# L == H
# fullSet, iter: 0 i: 200, pairs changed 1
# L == H
# fullSet, iter: 0 i: 201, pairs changed 1
# L == H
# fullSet, iter: 0 i: 202, pairs changed 1
# L == H
# fullSet, iter: 0 i: 203, pairs changed 1
# L == H
# fullSet, iter: 0 i: 204, pairs changed 1
# L == H
# fullSet, iter: 0 i: 205, pairs changed 1
# L == H
# fullSet, iter: 0 i: 206, pairs changed 1
# L == H
# fullSet, iter: 0 i: 207, pairs changed 1
# L == H
# fullSet, iter: 0 i: 208, pairs changed 1
# L == H
# fullSet, iter: 0 i: 209, pairs changed 1
# L == H
# fullSet, iter: 0 i: 210, pairs changed 1
# L == H
# fullSet, iter: 0 i: 211, pairs changed 1
# L == H
# fullSet, iter: 0 i: 212, pairs changed 1
# L == H
# fullSet, iter: 0 i: 213, pairs changed 1
# L == H
# fullSet, iter: 0 i: 214, pairs changed 1
# L == H
# fullSet, iter: 0 i: 215, pairs changed 1
# L == H
# fullSet, iter: 0 i: 216, pairs changed 1
# L == H
# fullSet, iter: 0 i: 217, pairs changed 1
# L == H
# fullSet, iter: 0 i: 218, pairs changed 1
# L == H
# fullSet, iter: 0 i: 219, pairs changed 1
# L == H
# fullSet, iter: 0 i: 220, pairs changed 1
# L == H
# fullSet, iter: 0 i: 221, pairs changed 1
# L == H
# fullSet, iter: 0 i: 222, pairs changed 1
# L == H
# fullSet, iter: 0 i: 223, pairs changed 1
# L == H
# fullSet, iter: 0 i: 224, pairs changed 1
# L == H
# fullSet, iter: 0 i: 225, pairs changed 1
# L == H
# fullSet, iter: 0 i: 226, pairs changed 1
# L == H
# fullSet, iter: 0 i: 227, pairs changed 1
# L == H
# fullSet, iter: 0 i: 228, pairs changed 1
# L == H
# fullSet, iter: 0 i: 229, pairs changed 1
# L == H
# fullSet, iter: 0 i: 230, pairs changed 1
# L == H
# fullSet, iter: 0 i: 231, pairs changed 1
# L == H
# fullSet, iter: 0 i: 232, pairs changed 1
# L == H
# fullSet, iter: 0 i: 233, pairs changed 1
# L == H
# fullSet, iter: 0 i: 234, pairs changed 1
# L == H
# fullSet, iter: 0 i: 235, pairs changed 1
# L == H
# fullSet, iter: 0 i: 236, pairs changed 1
# L == H
# fullSet, iter: 0 i: 237, pairs changed 1
# L == H
# fullSet, iter: 0 i: 238, pairs changed 1
# L == H
# fullSet, iter: 0 i: 239, pairs changed 1
# L == H
# fullSet, iter: 0 i: 240, pairs changed 1
# L == H
# fullSet, iter: 0 i: 241, pairs changed 1
# L == H
# fullSet, iter: 0 i: 242, pairs changed 1
# L == H
# fullSet, iter: 0 i: 243, pairs changed 1
# L == H
# fullSet, iter: 0 i: 244, pairs changed 1
# L == H
# fullSet, iter: 0 i: 245, pairs changed 1
# L == H
# fullSet, iter: 0 i: 246, pairs changed 1
# L == H
# fullSet, iter: 0 i: 247, pairs changed 1
# L == H
# fullSet, iter: 0 i: 248, pairs changed 1
# L == H
# fullSet, iter: 0 i: 249, pairs changed 1
# L == H
# fullSet, iter: 0 i: 250, pairs changed 1
# L == H
# fullSet, iter: 0 i: 251, pairs changed 1
# L == H
# fullSet, iter: 0 i: 252, pairs changed 1
# L == H
# fullSet, iter: 0 i: 253, pairs changed 1
# L == H
# fullSet, iter: 0 i: 254, pairs changed 1
# L == H
# fullSet, iter: 0 i: 255, pairs changed 1
# L == H
# fullSet, iter: 0 i: 256, pairs changed 1
# L == H
# fullSet, iter: 0 i: 257, pairs changed 1
# L == H
# fullSet, iter: 0 i: 258, pairs changed 1
# L == H
# fullSet, iter: 0 i: 259, pairs changed 1
# L == H
# fullSet, iter: 0 i: 260, pairs changed 1
# L == H
# fullSet, iter: 0 i: 261, pairs changed 1
# L == H
# fullSet, iter: 0 i: 262, pairs changed 1
# L == H
# fullSet, iter: 0 i: 263, pairs changed 1
# L == H
# fullSet, iter: 0 i: 264, pairs changed 1
# L == H
# fullSet, iter: 0 i: 265, pairs changed 1
# L == H
# fullSet, iter: 0 i: 266, pairs changed 1
# L == H
# fullSet, iter: 0 i: 267, pairs changed 1
# L == H
# fullSet, iter: 0 i: 268, pairs changed 1
# L == H
# fullSet, iter: 0 i: 269, pairs changed 1
# L == H
# fullSet, iter: 0 i: 270, pairs changed 1
# L == H
# fullSet, iter: 0 i: 271, pairs changed 1
# L == H
# fullSet, iter: 0 i: 272, pairs changed 1
# L == H
# fullSet, iter: 0 i: 273, pairs changed 1
# L == H
# fullSet, iter: 0 i: 274, pairs changed 1
# L == H
# fullSet, iter: 0 i: 275, pairs changed 1
# L == H
# fullSet, iter: 0 i: 276, pairs changed 1
# L == H
# fullSet, iter: 0 i: 277, pairs changed 1
# L == H
# fullSet, iter: 0 i: 278, pairs changed 1
# L == H
# fullSet, iter: 0 i: 279, pairs changed 1
# L == H
# fullSet, iter: 0 i: 280, pairs changed 1
# L == H
# fullSet, iter: 0 i: 281, pairs changed 1
# L == H
# fullSet, iter: 0 i: 282, pairs changed 1
# L == H
# fullSet, iter: 0 i: 283, pairs changed 1
# L == H
# fullSet, iter: 0 i: 284, pairs changed 1
# L == H
# fullSet, iter: 0 i: 285, pairs changed 1
# L == H
# fullSet, iter: 0 i: 286, pairs changed 1
# L == H
# fullSet, iter: 0 i: 287, pairs changed 1
# L == H
# fullSet, iter: 0 i: 288, pairs changed 1
# L == H
# fullSet, iter: 0 i: 289, pairs changed 1
# L == H
# fullSet, iter: 0 i: 290, pairs changed 1
# L == H
# fullSet, iter: 0 i: 291, pairs changed 1
# L == H
# fullSet, iter: 0 i: 292, pairs changed 1
# L == H
# fullSet, iter: 0 i: 293, pairs changed 1
# L == H
# fullSet, iter: 0 i: 294, pairs changed 1
# L == H
# fullSet, iter: 0 i: 295, pairs changed 1
# L == H
# fullSet, iter: 0 i: 296, pairs changed 1
# L == H
# fullSet, iter: 0 i: 297, pairs changed 1
# L == H
# fullSet, iter: 0 i: 298, pairs changed 1
# L == H
# fullSet, iter: 0 i: 299, pairs changed 1
# L == H
# fullSet, iter: 0 i: 300, pairs changed 1
# L == H
# fullSet, iter: 0 i: 301, pairs changed 1
# L == H
# fullSet, iter: 0 i: 302, pairs changed 1
# L == H
# fullSet, iter: 0 i: 303, pairs changed 1
# L == H
# fullSet, iter: 0 i: 304, pairs changed 1
# L == H
# fullSet, iter: 0 i: 305, pairs changed 1
# L == H
# fullSet, iter: 0 i: 306, pairs changed 1
# L == H
# fullSet, iter: 0 i: 307, pairs changed 1
# L == H
# fullSet, iter: 0 i: 308, pairs changed 1
# L == H
# fullSet, iter: 0 i: 309, pairs changed 1
# L == H
# fullSet, iter: 0 i: 310, pairs changed 1
# L == H
# fullSet, iter: 0 i: 311, pairs changed 1
# L == H
# fullSet, iter: 0 i: 312, pairs changed 1
# L == H
# fullSet, iter: 0 i: 313, pairs changed 1
# L == H
# fullSet, iter: 0 i: 314, pairs changed 1
# L == H
# fullSet, iter: 0 i: 315, pairs changed 1
# L == H
# fullSet, iter: 0 i: 316, pairs changed 1
# L == H
# fullSet, iter: 0 i: 317, pairs changed 1
# L == H
# fullSet, iter: 0 i: 318, pairs changed 1
# L == H
# fullSet, iter: 0 i: 319, pairs changed 1
# L == H
# fullSet, iter: 0 i: 320, pairs changed 1
# L == H
# fullSet, iter: 0 i: 321, pairs changed 1
# L == H
# fullSet, iter: 0 i: 322, pairs changed 1
# L == H
# fullSet, iter: 0 i: 323, pairs changed 1
# L == H
# fullSet, iter: 0 i: 324, pairs changed 1
# L == H
# fullSet, iter: 0 i: 325, pairs changed 1
# L == H
# fullSet, iter: 0 i: 326, pairs changed 1
# L == H
# fullSet, iter: 0 i: 327, pairs changed 1
# L == H
# fullSet, iter: 0 i: 328, pairs changed 1
# L == H
# fullSet, iter: 0 i: 329, pairs changed 1
# L == H
# fullSet, iter: 0 i: 330, pairs changed 1
# L == H
# fullSet, iter: 0 i: 331, pairs changed 1
# L == H
# fullSet, iter: 0 i: 332, pairs changed 1
# L == H
# fullSet, iter: 0 i: 333, pairs changed 1
# L == H
# fullSet, iter: 0 i: 334, pairs changed 1
# L == H
# fullSet, iter: 0 i: 335, pairs changed 1
# L == H
# fullSet, iter: 0 i: 336, pairs changed 1
# L == H
# fullSet, iter: 0 i: 337, pairs changed 1
# L == H
# fullSet, iter: 0 i: 338, pairs changed 1
# L == H
# fullSet, iter: 0 i: 339, pairs changed 1
# L == H
# fullSet, iter: 0 i: 340, pairs changed 1
# L == H
# fullSet, iter: 0 i: 341, pairs changed 1
# L == H
# fullSet, iter: 0 i: 342, pairs changed 1
# L == H
# fullSet, iter: 0 i: 343, pairs changed 1
# L == H
# fullSet, iter: 0 i: 344, pairs changed 1
# L == H
# fullSet, iter: 0 i: 345, pairs changed 1
# L == H
# fullSet, iter: 0 i: 346, pairs changed 1
# L == H
# fullSet, iter: 0 i: 347, pairs changed 1
# L == H
# fullSet, iter: 0 i: 348, pairs changed 1
# L == H
# fullSet, iter: 0 i: 349, pairs changed 1
# L == H
# fullSet, iter: 0 i: 350, pairs changed 1
# L == H
# fullSet, iter: 0 i: 351, pairs changed 1
# L == H
# fullSet, iter: 0 i: 352, pairs changed 1
# L == H
# fullSet, iter: 0 i: 353, pairs changed 1
# L == H
# fullSet, iter: 0 i: 354, pairs changed 1
# L == H
# fullSet, iter: 0 i: 355, pairs changed 1
# L == H
# fullSet, iter: 0 i: 356, pairs changed 1
# L == H
# fullSet, iter: 0 i: 357, pairs changed 1
# L == H
# fullSet, iter: 0 i: 358, pairs changed 1
# L == H
# fullSet, iter: 0 i: 359, pairs changed 1
# L == H
# fullSet, iter: 0 i: 360, pairs changed 1
# L == H
# fullSet, iter: 0 i: 361, pairs changed 1
# L == H
# fullSet, iter: 0 i: 362, pairs changed 1
# L == H
# fullSet, iter: 0 i: 363, pairs changed 1
# L == H
# fullSet, iter: 0 i: 364, pairs changed 1
# L == H
# fullSet, iter: 0 i: 365, pairs changed 1
# L == H
# fullSet, iter: 0 i: 366, pairs changed 1
# L == H
# fullSet, iter: 0 i: 367, pairs changed 1
# L == H
# fullSet, iter: 0 i: 368, pairs changed 1
# L == H
# fullSet, iter: 0 i: 369, pairs changed 1
# L == H
# fullSet, iter: 0 i: 370, pairs changed 1
# L == H
# fullSet, iter: 0 i: 371, pairs changed 1
# L == H
# fullSet, iter: 0 i: 372, pairs changed 1
# L == H
# fullSet, iter: 0 i: 373, pairs changed 1
# L == H
# fullSet, iter: 0 i: 374, pairs changed 1
# L == H
# fullSet, iter: 0 i: 375, pairs changed 1
# L == H
# fullSet, iter: 0 i: 376, pairs changed 1
# L == H
# fullSet, iter: 0 i: 377, pairs changed 1
# L == H
# fullSet, iter: 0 i: 378, pairs changed 1
# L == H
# fullSet, iter: 0 i: 379, pairs changed 1
# L == H
# fullSet, iter: 0 i: 380, pairs changed 1
# L == H
# fullSet, iter: 0 i: 381, pairs changed 1
# L == H
# fullSet, iter: 0 i: 382, pairs changed 1
# L == H
# fullSet, iter: 0 i: 383, pairs changed 1
# L == H
# fullSet, iter: 0 i: 384, pairs changed 1
# L == H
# fullSet, iter: 0 i: 385, pairs changed 1
# L == H
# fullSet, iter: 0 i: 386, pairs changed 1
# L == H
# fullSet, iter: 0 i: 387, pairs changed 1
# L == H
# fullSet, iter: 0 i: 388, pairs changed 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-92284b5049e6> in <module>()
# ----> 1 testDigits(('rbf', 20))
#
# <ipython-input-8-287d523e9b2b> in testDigits(kTup)
#      17 def testDigits(kTup=('rbf', 10)):
#      18     dataArr, labelArr = loadImages('digits/trainingDigits')
# ---> 19     b, alphas = smoP(dataArr, labelArr, 200, 0.0001, 1000, kTup)
#      20     datMat = np.mat(dataArr)
#      21     labelMat = np.mat(labelArr).transpose()
#
# <ipython-input-5-ab9da97a4dcb> in smoP(dataMatIn, classLabels, C, toler, maxIter, kTup)
#       8         if entireSet:    # 遍历所有值
#       9             for i in range(oS.m):
# ---> 10                 alphaPairsChanged += innerL(i,oS)
#      11                 print('fullSet, iter: %d i: %d, pairs changed %d' % (iter, i, alphaPairsChanged))
#      12             iter += 1
#
# <ipython-input-4-ff4a17922b59> in innerL(i, oS)
#       2     Ei = calcEk(oS, i)
#       3     if ((oS.labelMat[i] * Ei < -oS.tol) and (oS.alphas[i] < oS.C)) or ((oS.labelMat[i] * Ei > oS.tol) and (oS.alphas[i] >0)):
# ----> 4         j ,Ej = selectJ(i, oS, Ei)
#       5         alphaIold = oS.alphas[i].copy()
#       6         alphaJold = oS.alphas[j].copy()
#
# <ipython-input-3-bfcb020b17ce> in selectJ(i, oS, Ei)
#      30             if k == i:
#      31                 continue
# ---> 32             Ek = calcEk(oS, k)
#      33             deltaE = abs(Ei - Ek)
#      34             if deltaE > maxDeltaE:    # 选择具有最大步长的j
#
# <ipython-input-3-bfcb020b17ce> in calcEk(oS, k)
#      15 # 计算E值并返回
#      16 def calcEk(oS, k):
# ---> 17     fXk = float(np.multiply(oS.alphas, oS.labelMat).T * oS.K[:, k] + oS.b)
#      18     Ek = fXk - float(oS.labelMat[k])
#      19     return Ek
#
# d:\Anaconda3\lib\site-packages\numpy\matrixlib\defmatrix.py in __mul__(self, other)
#     307         if isinstance(other, (N.ndarray, list, tuple)) :
#     308             # This promotes 1-D vectors to row vectors
# --> 309             return N.dot(self, asmatrix(other))
#     310         if isscalar(other) or not hasattr(other, '__rmul__') :
#     311             return N.dot(self, other)
#
# KeyboardInterrupt:
